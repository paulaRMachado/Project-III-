# %%
import src.extraction as extract
import src.cleaning as clean
import src.visualization as viz

# %%
startup_loc = extract.start_ups("San Francisco")
start_ups = clean.basic_clean(startup_loc)

# %%
map1 = viz.start_ups_map(start_ups)

# %%
possible_loc = extract.possible_offices("San Francisco")
possible_offices = start_ups = clean.basic_clean(possible_loc)

# %%
map2 = viz.possible_venues_map(possible_offices)

# %%
map3 = viz.separate_heatmaps(possible_offices)

# %%
map4 = viz.condensed_heatmaps(possible_offices)

# %%
shortlist = extract.short_list()
address = "685, Market Street, San Francisco"
coffee_near = extract.venue_near("starbucks", address)
bar_near = extract.venue_catg_near("13003", address)
night_near = extract.venue_catg_near("10032", address)

# %%
map5 = viz.short_list_map(shortlist,coffee_near,night_near, bar_near)
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd8a884bf5752b4400d8d58c87fc0203 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd8a884bf5752b4400d8d58c87fc0203&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd8a884bf5752b4400d8d58c87fc0203 = L.map(
#                 &quot;map_bd8a884bf5752b4400d8d58c87fc0203&quot;,
#                 {
#                     center: [37.7903715, -122.4029651],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#
#
#
#             var tile_layer_a8e7ed476915d4639cd3791bc199708b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#             var marker_cae60c58ea501c15f8e2df8816bb0656 = L.marker(
#                 [37.788668, -122.400558],
#                 {}
#             ).addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#             var icon_a59319d03b0a135c7a7ae5e687f8fb69 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cae60c58ea501c15f8e2df8816bb0656.setIcon(icon_a59319d03b0a135c7a7ae5e687f8fb69);
#
#
#             marker_cae60c58ea501c15f8e2df8816bb0656.bindTooltip(
#                 `&lt;div&gt;
#                      hi5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7901bece218bc5b6d6f1cf8ef13985cf = L.marker(
#                 [37.787683, -122.410943],
#                 {}
#             ).addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#             var icon_765d15c7c2bba3ef0f783d6fdb5b02e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7901bece218bc5b6d6f1cf8ef13985cf.setIcon(icon_765d15c7c2bba3ef0f783d6fdb5b02e5);
#
#
#             marker_7901bece218bc5b6d6f1cf8ef13985cf.bindTooltip(
#                 `&lt;div&gt;
#                      eBuddy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9768430783692c96b8d5f5121ef14460 = L.marker(
#                 [37.7898499, -122.4006831],
#                 {}
#             ).addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#             var icon_a387f8ad69e73e7cd67d4c8e750e1761 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9768430783692c96b8d5f5121ef14460.setIcon(icon_a387f8ad69e73e7cd67d4c8e750e1761);
#
#
#             marker_9768430783692c96b8d5f5121ef14460.bindTooltip(
#                 `&lt;div&gt;
#                      Twilio
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e63f8107e43edf5c813c6c4cd1695359 = L.marker(
#                 [37.787646, -122.402759],
#                 {}
#             ).addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#             var icon_c1ebe4ab9ac965987ed27edd18dfe499 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e63f8107e43edf5c813c6c4cd1695359.setIcon(icon_c1ebe4ab9ac965987ed27edd18dfe499);
#
#
#             marker_e63f8107e43edf5c813c6c4cd1695359.bindTooltip(
#                 `&lt;div&gt;
#                      Exent
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3f1d411dd7bf7b1a277f71935dd57dcb = L.marker(
#                 [37.784117, -122.407356],
#                 {}
#             ).addTo(map_bd8a884bf5752b4400d8d58c87fc0203);
#
#
#             var icon_cd8b6e08cfdb688812a34c9d527a056f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee &quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3f1d4
